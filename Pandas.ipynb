# %% [markdown]
# # Pandas Definition : Data of Individual, Organisation or Domain generated data over a period of time called Panel data.
#
# # data
#
# > excel : semi structured data
#
# > CSV : plain text file
#
# >  database table : pure structured data
#
# > html table : semi structured data
#
# e.t.c

# %%
import pandas as pd

# %%
pd.read_excel("student_data.xlsx")
# Out:
#       PRN    NAME  COURSE BRANCH SESSION  10th Marks  12th Marks  Total Fee
# 0   SUS52   Anand  B.Tech    CSE   19-23         368         337      75000
# 1   SUS13   Megha  B.Tech    CSE   19-23         430         355      70000
# 2   SUS59  Shivam  B.Tech    CSE   19-23         322         312      70000
# 3   SUS56    Arti  B.Tech    CSE   19-23         411         399      70000
# 4   SUS32    Guru  B.Tech    CSE   19-23         370         403      70000
# 5   SUS44  Ritesh     BCA     IT   19-22         305         345      55000
# 6   SUS11  Deepak     BCA     IT   20-23         302         310      55000
# 7  SUS172  Aryant  B.Tech     ME   19-23         255         268      70000

# %%
pd.read_excel("student_data.xlsx",sheet_name="Sheet2")
# Out:
#     C  C++  Java  Python   Database  DSA  Total Marks
# 0  85   62    65       98        85   45          440
# 1  65   45    92       52        74   69          397
# 2  88   92    74       41        32   20          347
# 3  65   14    41       47        85   49          301
# 4  85   97    45       32        56   45          360
# 5  35   42    45       74        85   14          295

# %%
df=pd.read_excel("student_data.xlsx",sheet_name=["Sheet1","Sheet2"])

# %%
df
# Out:
# {'Sheet1':       PRN    NAME  COURSE BRANCH SESSION  10th Marks  12th Marks  Total Fee
#  0   SUS52   Anand  B.Tech    CSE   19-23         368         337      75000
#  1   SUS13   Megha  B.Tech    CSE   19-23         430         355      70000
#  2   SUS59  Shivam  B.Tech    CSE   19-23         322         312      70000
#  3   SUS56    Arti  B.Tech    CSE   19-23         411         399      70000
#  4   SUS32    Guru  B.Tech    CSE   19-23         370         403      70000
#  5   SUS44  Ritesh     BCA     IT   19-22         305         345      55000
#  6   SUS11  Deepak     BCA     IT   20-23         302         310      55000
#  7  SUS172  Aryant  B.Tech     ME   19-23         255         268      70000,
#  'Sheet2':     C  C++  Java  Python   Database  DSA  Total Marks
#  0  85   62    65       98        85   45          440
#  1  65   45    92       52        74   69          397
#  2  88   92    74       41        32   20          347
# ...

# %%
df['Sheet1']
# Out:
#       PRN    NAME  COURSE BRANCH SESSION  10th Marks  12th Marks  Total Fee
# 0   SUS52   Anand  B.Tech    CSE   19-23         368         337      75000
# 1   SUS13   Megha  B.Tech    CSE   19-23         430         355      70000
# 2   SUS59  Shivam  B.Tech    CSE   19-23         322         312      70000
# 3   SUS56    Arti  B.Tech    CSE   19-23         411         399      70000
# 4   SUS32    Guru  B.Tech    CSE   19-23         370         403      70000
# 5   SUS44  Ritesh     BCA     IT   19-22         305         345      55000
# 6   SUS11  Deepak     BCA     IT   20-23         302         310      55000
# 7  SUS172  Aryant  B.Tech     ME   19-23         255         268      70000

# %%
df['Sheet2']
# Out:
#     C  C++  Java  Python   Database  DSA  Total Marks
# 0  85   62    65       98        85   45          440
# 1  65   45    92       52        74   69          397
# 2  88   92    74       41        32   20          347
# 3  65   14    41       47        85   49          301
# 4  85   97    45       32        56   45          360
# 5  35   42    45       74        85   14          295

# %%
df1=pd.read_excel("student_data.xlsx",sheet_name=0)

# %%
df1
# Out:
#       PRN    NAME  COURSE BRANCH SESSION  10th Marks  12th Marks  Total Fee
# 0   SUS52   Anand  B.Tech    CSE   19-23         368         337      75000
# 1   SUS13   Megha  B.Tech    CSE   19-23         430         355      70000
# 2   SUS59  Shivam  B.Tech    CSE   19-23         322         312      70000
# 3   SUS56    Arti  B.Tech    CSE   19-23         411         399      70000
# 4   SUS32    Guru  B.Tech    CSE   19-23         370         403      70000
# 5   SUS44  Ritesh     BCA     IT   19-22         305         345      55000
# 6   SUS11  Deepak     BCA     IT   20-23         302         310      55000
# 7  SUS172  Aryant  B.Tech     ME   19-23         255         268      70000

# %%
df2=pd.read_excel("student_data.xlsx",sheet_name=[0,1])

# %%
df2
# Out:
# {0:       PRN    NAME  COURSE BRANCH SESSION  10th Marks  12th Marks  Total Fee
#  0   SUS52   Anand  B.Tech    CSE   19-23         368         337      75000
#  1   SUS13   Megha  B.Tech    CSE   19-23         430         355      70000
#  2   SUS59  Shivam  B.Tech    CSE   19-23         322         312      70000
#  3   SUS56    Arti  B.Tech    CSE   19-23         411         399      70000
#  4   SUS32    Guru  B.Tech    CSE   19-23         370         403      70000
#  5   SUS44  Ritesh     BCA     IT   19-22         305         345      55000
#  6   SUS11  Deepak     BCA     IT   20-23         302         310      55000
#  7  SUS172  Aryant  B.Tech     ME   19-23         255         268      70000,
#  1:     C  C++  Java  Python   Database  DSA  Total Marks
#  0  85   62    65       98        85   45          440
#  1  65   45    92       52        74   69          397
#  2  88   92    74       41        32   20          347
# ...

# %%
df2[0]
# Out:
#       PRN    NAME  COURSE BRANCH SESSION  10th Marks  12th Marks  Total Fee
# 0   SUS52   Anand  B.Tech    CSE   19-23         368         337      75000
# 1   SUS13   Megha  B.Tech    CSE   19-23         430         355      70000
# 2   SUS59  Shivam  B.Tech    CSE   19-23         322         312      70000
# 3   SUS56    Arti  B.Tech    CSE   19-23         411         399      70000
# 4   SUS32    Guru  B.Tech    CSE   19-23         370         403      70000
# 5   SUS44  Ritesh     BCA     IT   19-22         305         345      55000
# 6   SUS11  Deepak     BCA     IT   20-23         302         310      55000
# 7  SUS172  Aryant  B.Tech     ME   19-23         255         268      70000

# %%
df2[1]
# Out:
#     C  C++  Java  Python   Database  DSA  Total Marks
# 0  85   62    65       98        85   45          440
# 1  65   45    92       52        74   69          397
# 2  88   92    74       41        32   20          347
# 3  65   14    41       47        85   49          301
# 4  85   97    45       32        56   45          360
# 5  35   42    45       74        85   14          295

# %%
df3=pd.read_excel("weather.xlsx")

# %%
df3
# Out:
#         Date  temperature  windspeed  event
# 0 2022-01-01         32.0        6.0   Rain
# 1 2022-01-02          NaN        9.0  Sunny
# 2 2022-01-03         28.0        NaN   Snow
# 3 2022-01-04          NaN        7.0    NaN
# 4 2022-01-05         32.0        NaN   Rain
# 5 2022-01-06          NaN        NaN  Sunny
# 6 2022-01-07          NaN        NaN    NaN
# 7 2022-01-08         34.0        8.0  Cloud
# 8 2022-01-09         40.0       12.0  Sunny
# 9 2022-01-10         30.0       10.0  Sunny

# %% [markdown]
# # deleting rows having NAN values

# %%
df3.dropna()
# Out:
#         Date  temperature  windspeed  event
# 0 2022-01-01         32.0        6.0   Rain
# 7 2022-01-08         34.0        8.0  Cloud
# 8 2022-01-09         40.0       12.0  Sunny
# 9 2022-01-10         30.0       10.0  Sunny

# %%
df3
# Out:
#         Date  temperature  windspeed  event
# 0 2022-01-01         32.0        6.0   Rain
# 1 2022-01-02          NaN        9.0  Sunny
# 2 2022-01-03         28.0        NaN   Snow
# 3 2022-01-04          NaN        7.0    NaN
# 4 2022-01-05         32.0        NaN   Rain
# 5 2022-01-06          NaN        NaN  Sunny
# 6 2022-01-07          NaN        NaN    NaN
# 7 2022-01-08         34.0        8.0  Cloud
# 8 2022-01-09         40.0       12.0  Sunny
# 9 2022-01-10         30.0       10.0  Sunny

# %% [markdown]
# # There are 2 ways to read a particular column
#
# > 1st way

# %%
df3.temperature
# Out:
# 0    32.0
# 1     NaN
# 2    28.0
# 3     NaN
# 4    32.0
# 5     NaN
# 6     NaN
# 7    34.0
# 8    40.0
# 9    30.0
# Name: temperature, dtype: float64

# %% [markdown]
# > 2nd way

# %%
df3['temperature']
# Out:
# 0    32.0
# 1     NaN
# 2    28.0
# 3     NaN
# 4    32.0
# 5     NaN
# 6     NaN
# 7    34.0
# 8    40.0
# 9    30.0
# Name: temperature, dtype: float64

# %% [markdown]
# # filling NAN values in temperature column with mean

# %%
# When inplace = True , the data is modified in place, 
# which means it will return nothing and the dataframe is now updated. 
# When inplace = False , which is the default, 
# then the operation is performed and it returns a copy of the object.

# %%
df3.temperature.fillna(df3.temperature.mean(),inplace=True)

# %%
df3
# Out:
#         Date  temperature  windspeed  event
# 0 2022-01-01    32.000000        6.0   Rain
# 1 2022-01-02    32.666667        9.0  Sunny
# 2 2022-01-03    28.000000        NaN   Snow
# 3 2022-01-04    32.666667        7.0    NaN
# 4 2022-01-05    32.000000        NaN   Rain
# 5 2022-01-06    32.666667        NaN  Sunny
# 6 2022-01-07    32.666667        NaN    NaN
# 7 2022-01-08    34.000000        8.0  Cloud
# 8 2022-01-09    40.000000       12.0  Sunny
# 9 2022-01-10    30.000000       10.0  Sunny

# %% [markdown]
# # filling NAN values in windspeed column with median

# %%
df3.windspeed.fillna(df3.windspeed.median(),inplace=True)

# %%
df3
# Out:
#         Date  temperature  windspeed  event
# 0 2022-01-01    32.000000        6.0   Rain
# 1 2022-01-02    32.666667        9.0  Sunny
# 2 2022-01-03    28.000000        8.5   Snow
# 3 2022-01-04    32.666667        7.0    NaN
# 4 2022-01-05    32.000000        8.5   Rain
# 5 2022-01-06    32.666667        8.5  Sunny
# 6 2022-01-07    32.666667        8.5    NaN
# 7 2022-01-08    34.000000        8.0  Cloud
# 8 2022-01-09    40.000000       12.0  Sunny
# 9 2022-01-10    30.000000       10.0  Sunny

# %% [markdown]
# # filling NAN values in event column with mode

# %%
df3.event.fillna(df3.event.mode(),inplace=True)

# %%
df3
# Out:
#         Date  temperature  windspeed  event
# 0 2022-01-01    32.000000        6.0   Rain
# 1 2022-01-02    32.666667        9.0  Sunny
# 2 2022-01-03    28.000000        8.5   Snow
# 3 2022-01-04    32.666667        7.0    NaN
# 4 2022-01-05    32.000000        8.5   Rain
# 5 2022-01-06    32.666667        8.5  Sunny
# 6 2022-01-07    32.666667        8.5    NaN
# 7 2022-01-08    34.000000        8.0  Cloud
# 8 2022-01-09    40.000000       12.0  Sunny
# 9 2022-01-10    30.000000       10.0  Sunny

# %%
df3.event.mode()
# Out:
# 0    Sunny
# dtype: object

# %%
df3.event.mode().values
# Out:
# array(['Sunny'], dtype=object)

# %%
df3.event.fillna(df3.event.mode().values[0],inplace=True)

# %%
df3
# Out:
#         Date  temperature  windspeed  event
# 0 2022-01-01    32.000000        6.0   Rain
# 1 2022-01-02    32.666667        9.0  Sunny
# 2 2022-01-03    28.000000        8.5   Snow
# 3 2022-01-04    32.666667        7.0  Sunny
# 4 2022-01-05    32.000000        8.5   Rain
# 5 2022-01-06    32.666667        8.5  Sunny
# 6 2022-01-07    32.666667        8.5  Sunny
# 7 2022-01-08    34.000000        8.0  Cloud
# 8 2022-01-09    40.000000       12.0  Sunny
# 9 2022-01-10    30.000000       10.0  Sunny

# %% [markdown]
# # Another way to fill NAN values

# %%
weather = pd.read_excel("weather.xlsx")

# %%
weather
# Out:
#         Date  temperature  windspeed  event
# 0 2022-01-01         32.0        6.0   Rain
# 1 2022-01-02          NaN        9.0  Sunny
# 2 2022-01-03         28.0        NaN   Snow
# 3 2022-01-04          NaN        7.0    NaN
# 4 2022-01-05         32.0        NaN   Rain
# 5 2022-01-06          NaN        NaN  Sunny
# 6 2022-01-07          NaN        NaN    NaN
# 7 2022-01-08         34.0        8.0  Cloud
# 8 2022-01-09         40.0       12.0  Sunny
# 9 2022-01-10         30.0       10.0  Sunny

# %%
weather.temperature
# Out:
# 0    32.0
# 1     NaN
# 2    28.0
# 3     NaN
# 4    32.0
# 5     NaN
# 6     NaN
# 7    34.0
# 8    40.0
# 9    30.0
# Name: temperature, dtype: float64

# %% [markdown]
# # Forward filling

# %%
weather
# Out:
#         Date  temperature  windspeed  event
# 0 2022-01-01         32.0        6.0   Rain
# 1 2022-01-02          NaN        9.0  Sunny
# 2 2022-01-03         28.0        NaN   Snow
# 3 2022-01-04          NaN        7.0    NaN
# 4 2022-01-05         32.0        NaN   Rain
# 5 2022-01-06          NaN        NaN  Sunny
# 6 2022-01-07          NaN        NaN    NaN
# 7 2022-01-08         34.0        8.0  Cloud
# 8 2022-01-09         40.0       12.0  Sunny
# 9 2022-01-10         30.0       10.0  Sunny

# %%
weather.temperature.ffill(inplace=True)

# %%
weather
# Out:
#         Date  temperature  windspeed  event
# 0 2022-01-01         32.0        6.0   Rain
# 1 2022-01-02         32.0        9.0  Sunny
# 2 2022-01-03         28.0        NaN   Snow
# 3 2022-01-04         28.0        7.0    NaN
# 4 2022-01-05         32.0        NaN   Rain
# 5 2022-01-06         32.0        NaN  Sunny
# 6 2022-01-07         32.0        NaN    NaN
# 7 2022-01-08         34.0        8.0  Cloud
# 8 2022-01-09         40.0       12.0  Sunny
# 9 2022-01-10         30.0       10.0  Sunny

# %% [markdown]
# # Backward filling

# %%
weather.windspeed.backfill()
# Out:
# 0     6.0
# 1     9.0
# 2     7.0
# 3     7.0
# 4     8.0
# 5     8.0
# 6     8.0
# 7     8.0
# 8    12.0
# 9    10.0
# Name: windspeed, dtype: float64

# %%
weather.windspeed.backfill(inplace=True)

# %%
weather
# Out:
#         Date  temperature  windspeed  event
# 0 2022-01-01         32.0        6.0   Rain
# 1 2022-01-02         32.0        9.0  Sunny
# 2 2022-01-03         28.0        7.0   Snow
# 3 2022-01-04         28.0        7.0    NaN
# 4 2022-01-05         32.0        8.0   Rain
# 5 2022-01-06         32.0        8.0  Sunny
# 6 2022-01-07         32.0        8.0    NaN
# 7 2022-01-08         34.0        8.0  Cloud
# 8 2022-01-09         40.0       12.0  Sunny
# 9 2022-01-10         30.0       10.0  Sunny

# %%
weather.backfill()
# Out:
#         Date  temperature  windspeed  event
# 0 2022-01-01         32.0        6.0   Rain
# 1 2022-01-02         32.0        9.0  Sunny
# 2 2022-01-03         28.0        7.0   Snow
# 3 2022-01-04         28.0        7.0   Rain
# 4 2022-01-05         32.0        8.0   Rain
# 5 2022-01-06         32.0        8.0  Sunny
# 6 2022-01-07         32.0        8.0  Cloud
# 7 2022-01-08         34.0        8.0  Cloud
# 8 2022-01-09         40.0       12.0  Sunny
# 9 2022-01-10         30.0       10.0  Sunny

# %%
weather=weather.backfill()

# %%
weather
# Out:
#         Date  temperature  windspeed  event
# 0 2022-01-01         32.0        6.0   Rain
# 1 2022-01-02         32.0        9.0  Sunny
# 2 2022-01-03         28.0        7.0   Snow
# 3 2022-01-04         28.0        7.0   Rain
# 4 2022-01-05         32.0        8.0   Rain
# 5 2022-01-06         32.0        8.0  Sunny
# 6 2022-01-07         32.0        8.0  Cloud
# 7 2022-01-08         34.0        8.0  Cloud
# 8 2022-01-09         40.0       12.0  Sunny
# 9 2022-01-10         30.0       10.0  Sunny

# %% [markdown]
# # checking duplicate values

# %%
weather.temperature.duplicated()
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4     True
# 5     True
# 6     True
# 7    False
# 8    False
# 9    False
# Name: temperature, dtype: bool

# %% [markdown]
# # removing duplicate values

# %%
weather.temperature.drop_duplicates()
# Out:
# 0    32.0
# 2    28.0
# 7    34.0
# 8    40.0
# 9    30.0
# Name: temperature, dtype: float64

# %%
weather.drop_duplicates(subset='temperature')
# Out:
#         Date  temperature  windspeed  event
# 0 2022-01-01         32.0        6.0   Rain
# 2 2022-01-03         28.0        7.0   Snow
# 7 2022-01-08         34.0        8.0  Cloud
# 8 2022-01-09         40.0       12.0  Sunny
# 9 2022-01-10         30.0       10.0  Sunny
